-- %%
%python
# To print a code
print("Python code")

-- %%
%python
# To print an integer
print(100)

-- %%
%python
# To get the help from python
help(print)

-- %%
%python
# a. To print the codes in multiple lines
print("This is just a code")
print("Multiple lines code")

-- %%
%python
# Writing multiple codes in the same line
print("This is just a code", end =", ")
print("This is the second sentence of the same line")
