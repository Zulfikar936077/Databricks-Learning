# %%
# Showing concatenation for string
print("Hello" + " " + "World!")

# %%
# Showing concatenation fro integers
print(1 + 2)

# %%
# converting a string into an integer
print(1 + int("2"))

# %%
# converting an integer into a string
print(str(1) + "2")
