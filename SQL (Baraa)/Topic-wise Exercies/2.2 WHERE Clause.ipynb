-- %%
-- Retrieve customers from Germany
SELECT 
    FirstName 
FROM workspace.github.customers 
WHERE Country = 'Germany'

-- %%
-- Retrieve customers from USA and score > 0
SELECT 
    FirstName,
    Score
FROM workspace.github.customers 
WHERE Country = 'USA' and Score > 0
