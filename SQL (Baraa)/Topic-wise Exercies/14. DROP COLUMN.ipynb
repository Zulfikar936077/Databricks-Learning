-- %%
-- Remove the phone column from the persons table
-- Enable column mapping to allow DROP COLUMN
ALTER TABLE persons_2 SET TBLPROPERTIES ('delta.columnMapping.mode' = 'name');

ALTER TABLE persons_2 
DROP COLUMN phone;

SELECT * FROM persons_2;
