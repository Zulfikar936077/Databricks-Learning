-- %%
-- a.Create a table
-- b. Create columns for the table
-- c. Insert values into the newly made table
CREATE TABLE my_employees (
  id INT NOT NULL,
  first_name VARCHAR(50),
  country VARCHAR(50),
  score INT
)

-- %%
SELECT * FROM my_employees;

-- %%
INSERT INTO my_employees (id, first_name, country, score) 
VALUES (1, 'John', 'USA', 100),
       (2, 'Jane', 'Canada', 200),
       (3, 'Bob', 'Mexico', 300);
SELECT * FROM my_employees;
