-- %%
-- Retrieve customers' score and number of customer per country. Sort the score in descending order and the country in ascending order
SELECT 
    Country,
    SUM(Score) AS Total_Score,
    COUNT(CustomerID) AS Number_Of_Customers
FROM workspace.github.customers
GROUP BY Country
ORDER BY 
    Total_Score DESC, 
    Country ASC
