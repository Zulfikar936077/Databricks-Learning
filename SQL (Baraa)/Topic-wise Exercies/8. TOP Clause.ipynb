-- %%
-- Show the top 3 customers based on score in Descending order
SELECT *
FROM workspace.github.customers
ORDER BY Score DESC
LIMIT 3

-- %%
-- Show the bottom 3 customers based on score in Descending order
SELECT *
FROM workspace.github.customers
WHERE Score != 0
ORDER BY Score ASC
LIMIT 3
