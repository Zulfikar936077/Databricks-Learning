-- %%
-- Find the average score of each country considering only customers with a score not equal to 0 and return only those countries with an average score greater than 430
SELECT Country,
       AVG(Score)
FROM workspace.github.customers
WHERE Score != 0
GROUP BY Country
HAVING AVG(Score) > 430
ORDER BY AVG(Score)
